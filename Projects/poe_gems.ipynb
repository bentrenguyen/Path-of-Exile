# %%
import pandas as pd
import pobapi

MAX_LEN = 48

# %%
all_gems = pd.read_json('PoEgems_Sentinel_2022-07-18.json')
all_gems.head()
# Out:
#                              name  \
# 0                      Absolution
# 1      Added Chaos Damage Support
# 2       Added Cold Damage Support
# 3       Added Fire Damage Support
# 4  Added Lightning Damage Support
#
#                                                 tags          price  \
# 0  [Spell, Minion, Duration, AoE, Physical, Light...  Transmutation
# 1                                   [Chaos, Support]        Alchemy
# 2                                    [Cold, Support]  Transmutation
# 3                          [Fire, Physical, Support]  Transmutation
# 4                               [Lightning, Support]  Transmutation
#
#                                              quality  cost costType  level  \
# 0  {'su': 'Minions deal (0–20)% increased Damage'...  9–26        m     12
# 1  {'su': 'Supported Skills deal (0–10)% increase...  120%      NaN     31
# 2  {'su': 'Supported Skills deal (0–10)% increase...  120%      NaN      8
# 3  {'su': 'Supported Skills deal (0–10)% increase...  120%      NaN      8
# 4  {'su': 'Supported Skills deal (0–10)% increase...  120%      NaN      8
#
#         colors weapons                                             quests  \
# 0  [Red, Blue]      []  [{'name': 'the_siren_s_cadence', 'classes': 'T...
# 1       [Blue]      []  [{'name': 'a_fixture_of_fate', 'classes': 'Due...
# 2      [Green]      []  [{'name': 'the_caged_brute', 'classes': 'Range...
# 3        [Red]      []  [{'name': 'the_caged_brute', 'classes': 'Dueli...
# 4       [Blue]      []  [{'name': 'the_caged_brute', 'classes': 'Scion...
#
#   jewels                                   uniques  \
# 0     []                                        []
# 1     []  [Duskblight, Night's Hold, The Covenant]
# 2     []                             [Bitterdream]
# 3     []                                 [Ashrend]
# 4     []                             [Thunderfist]
#
#                                         enchantments  instant  \
# 0  {'m': ['8% increased Absolution Cast Speed', '...    False
# 1                                                 {}    False
# 2                                                 {}    False
# 3                                                 {}    False
# 4                                                 {}    False
#
#                                                  src icon league
# 0  WzI1LDE0LHsiZiI6IjJESXRlbXMvR2Vtcy9BYnNvbHV0aW...  NaN    NaN
# 1  WzI1LDE0LHsiZiI6IjJESXRlbXMvR2Vtcy9TdXBwb3J0L0...    H    NaN
# 2  WzI1LDE0LHsiZiI6IjJESXRlbXMvR2Vtcy9TdXBwb3J0L0...    C    NaN
# 3  WzI1LDE0LHsiZiI6IjJESXRlbXMvR2Vtcy9TdXBwb3J0L0...    F    NaN
# 4  WzI1LDE0LHsiZiI6IjJESXRlbXMvR2Vtcy9TdXBwb3J0L0...    L    NaN

# %%
def gemSort(all_gems):
    red1, red2, green1, green2, blue1, blue2 = [], [], [], [], [], []
    for index, row in all_gems.iterrows():
        name = str.lower(row['name'])
        color = row['colors'][0]
        isSupport = False
        if "vaal " in name: 
            continue
        elif "awakened " in name: 
            continue
        if 'Support' in row['tags']:
            isSupport = True
        if not isSupport: 
            if color == 'Red':
                red1.append(name)
            elif color == 'Blue': 
                blue1.append(name)
            elif color == 'Green': 
                green1.append(name)
        else:
            ## add/remove support text 
            #split_name = str.split(name, " support")[0]
            split_name = name
            if color == 'Red':
                red2.append(split_name)
            elif color == 'Blue': 
                blue2.append(split_name)
            elif color == 'Green': 
                green2.append(split_name)
    sorted_gems = [red1, red2, green1, green2, blue1, blue2]
    return sorted_gems

sorted_gems = gemSort(all_gems)

# %%
lst = []
for gemlst in sorted_gems:
    lst += gemlst
lst
# Out:
# ['absolution',
#  'ancestral cry',
#  'ancestral protector',
#  'ancestral warchief',
#  'anger',
#  'animate guardian',
#  'battlemages cry',
#  'berserk',
#  'bladestorm',
#  'blood and sand',
#  'boneshatter',
#  'chain hook',
#  'cleave',
#  'consecrated path',
#  'corrupting fever',
#  'decoy totem',
#  'defiance banner',
#  'determination',
#  'devouring totem',
#  'dominating blow',
#  'dread banner',
#  'earthquake',
#  'earthshatter',
#  'enduring cry',
#  'exsanguinate',
#  'flame link',
#  'flesh and stone',
#  'generals cry',
#  'glacial hammer',
#  'ground slam',
#  'heavy strike',
#  'herald of ash',
#  'herald of purity',
#  'holy flame totem',
#  'ice crash',
#  'immortal call',
#  'infernal blow',
#  'infernal cry',
#  'intimidating cry',
#  'leap slam',
#  'molten shell',
#  'molten strike',
#  'perforate',
#  'petrified blood',
#  'pride',
#  'protective link',
#  'punishment',
#  'purity of fire',
#  'rage vortex',
#  'rallying cry',
#  'reap',
#  'reckoning',
#  'rejuvenation totem',
#  'searing bond',
#  'seismic cry',
#  'shield charge',
#  'shield crush',
#  'shockwave totem',
#  'smite',
#  'static strike',
#  'steelskin',
#  'summon flame golem',
#  'summon stone golem',
#  'sunder',
#  'sweep',
#  'tectonic slam',
#  'vengeance',
#  'vigilant strike',
#  'vitality',
#  'vulnerability',
#  'war banner',
#  'warlords mark',
#  'added fire damage support',
#  'ancestral call support',
#  'arrogance support',
#  'ballista totem support',
#  'behead support',
#  'bloodlust support',
#  'bloodthirst support',
#  'brutality support',
#  'burning damage support',
#  'cast on melee kill support',
#  'cast when damage taken support',
#  'chance to bleed support',
#  'cold to fire support',
#  'cruelty support',
#  'damage on full life support',
#  'divine blessing support',
#  'earthbreaker support',
#  'elemental damage with attacks support',
#  'empower support',
#  'endurance charge on melee stun support',
#  'eternal blessing support',
#  'fire penetration support',
#  'fist of war support',
#  'fortify support',
#  'generosity support',
#  'increased duration support',
#  'inspiration support',
#  'iron grip support',
#  'iron will support',
#  'knockback support',
#  'less duration support',
#  'life gain on hit support',
#  'life leech support',
#  'lifetap support',
#  'maim support',
#  'melee physical damage support',
#  'melee splash support',
#  'multiple totems support',
#  'multistrike support',
#  'pulverise support',
#  'rage support',
#  'ruthless support',
#  'shockwave support',
#  'spell totem support',
#  'stun support',
#  'urgent orders support',
#  'ambush',
#  'animate weapon',
#  'arctic armour',
#  'artillery ballista',
#  'barrage',
#  'bear trap',
#  'blade blast',
#  'blade flurry',
#  'blade trap',
#  'blade vortex',
#  'bladefall',
#  'blast rain',
#  'blink arrow',
#  'blood rage',
#  'burning arrow',
#  'caustic arrow',
#  'charged dash',
#  'cobra lash',
#  'cremation',
#  'cyclone',
#  'dash',
#  'desecrate',
#  'detonate dead',
#  'double strike',
#  'dual strike',
#  'elemental hit',
#  'ensnaring arrow',
#  'ethereal knives',
#  'explosive arrow',
#  'explosive concoction',
#  'explosive trap',
#  'fire trap',
#  'flamethrower trap',
#  'flicker strike',
#  'frenzy',
#  'frost blades',
#  'galvanic arrow',
#  'grace',
#  'haste',
#  'hatred',
#  'herald of agony',
#  'herald of ice',
#  'ice shot',
#  'ice trap',
#  'intuitive link',
#  'lacerate',
#  'lancing steel',
#  'lightning arrow',
#  'lightning strike',
#  'mirror arrow',
#  'pestilent strike',
#  'phase run',
#  'plague bearer',
#  'poachers mark',
#  'poisonous concoction',
#  'precision',
#  'puncture',
#  'purity of ice',
#  'rain of arrows',
#  'reave',
#  'riposte',
#  'scourge arrow',
#  'seismic trap',
#  'shattering steel',
#  'shrapnel ballista',
#  'siege ballista',
#  'smoke mine',
#  'snipers mark',
#  'spectral helix',
#  'spectral shield throw',
#  'spectral throw',
#  'split arrow',
#  'splitting steel',
#  'storm rain',
#  'summon ice golem',
#  'temporal chains',
#  'temporal rift',
#  'tornado',
#  'tornado shot',
#  'toxic rain',
#  'unearth',
#  'vampiric link',
#  'venom gyre',
#  'viper strike',
#  'volatile dead',
#  'whirling blades',
#  'wild strike',
#  'withering step',
#  'added cold damage support',
#  'additional accuracy support',
#  'advanced traps support',
#  'arrow nova support',
#  'barrage support',
#  'blind support',
#  'block chance reduction support',
#  'cast on critical strike support',
#  'cast on death support',
#  'chain support',
#  'chance to flee support',
#  'chance to poison support',
#  'charged traps support',
#  'close combat support',
#  'cluster traps support',
#  'cold penetration support',
#  'critical strike affliction support',
#  'culling strike support',
#  'deadly ailments support',
#  'enhance support',
#  'faster attacks support',
#  'faster projectiles support',
#  'focused ballista support',
#  'fork support',
#  'greater multiple projectiles support',
#  'greater volley support',
#  'hypothermia support',
#  'ice bite support',
#  'impale support',
#  'lesser multiple projectiles support',
#  'mana leech support',
#  'mark on hit support',
#  'mirage archer support',
#  'multiple traps support',
#  'nightblade support',
#  'onslaught support',
#  'pierce support',
#  'point blank support',
#  'second wind support',
#  'slower projectiles support',
#  'swift affliction support',
#  'swift assembly support',
#  'trap and mine damage support',
#  'trap support',
#  'vicious projectiles support',
#  'vile toxins support',
#  'void manipulation support',
#  'volley support',
#  'withering touch support',
#  'arc',
#  'arcane cloak',
#  'arcanist brand',
#  'armageddon brand',
#  'assassins mark',
#  'ball lightning',
#  'bane',
#  'blazing salvo',
#  'blight',
#  'bodyswap',
#  'bone offering',
#  'brand recall',
#  'clarity',
#  'cold snap',
#  'conductivity',
#  'contagion',
#  'conversion trap',
#  'convocation',
#  'crackling lance',
#  'creeping frost',
#  'dark pact',
#  'despair',
#  'destructive link',
#  'discharge',
#  'discipline',
#  'divine ire',
#  'elemental weakness',
#  'energy blade',
#  'enfeeble',
#  'essence drain',
#  'eye of winter',
#  'fireball',
#  'firestorm',
#  'flame dash',
#  'flame surge',
#  'flame wall',
#  'flameblast',
#  'flammability',
#  'flesh offering',
#  'forbidden rite',
#  'freezing pulse',
#  'frost bomb',
#  'frost shield',
#  'frost wall',
#  'frostbite',
#  'frostblink',
#  'frostbolt',
#  'glacial cascade',
#  'herald of thunder',
#  'hexblast',
#  'hydrosphere',
#  'ice nova',
#  'ice spear',
#  'icicle mine',
#  'incinerate',
#  'kinetic blast',
#  'kinetic bolt',
#  'lightning spire trap',
#  'lightning tendrils',
#  'lightning trap',
#  'lightning warp',
#  'malevolence',
#  'manabond',
#  'orb of storms',
#  'penance brand',
#  'power siphon',
#  'purifying flame',
#  'purity of elements',
#  'purity of lightning',
#  'pyroclast mine',
#  'raise spectre',
#  'raise zombie',
#  'righteous fire',
#  'rolling magma',
#  'scorching ray',
#  'shock nova',
#  'sigil of power',
#  'siphoning trap',
#  'soul link',
#  'soulrend',
#  'spark',
#  'spellslinger',
#  'spirit offering',
#  'storm brand',
#  'storm burst',
#  'storm call',
#  'stormbind',
#  'stormblast mine',
#  'summon carrion golem',
#  'summon chaos golem',
#  'summon holy relic',
#  'summon lightning golem',
#  'summon raging spirit',
#  'summon reaper',
#  'summon skeletons',
#  'summon skitterbots',
#  'tempest shield',
#  'void sphere',
#  'voltaxic burst',
#  'vortex',
#  'wave of conviction',
#  'winter orb',
#  'wintertide brand',
#  'wither',
#  'wrath',
#  'zealotry',
#  'added chaos damage support',
#  'added lightning damage support',
#  'arcane surge support',
#  'archmage support',
#  'blasphemy support',
#  'blastchain mine support',
#  'bonechill support',
#  'cast when stunned support',
#  'cast while channelling support',
#  'charged mines support',
#  'combustion support',
#  'concentrated effect support',
#  'controlled destruction support',
#  'decay support',
#  'efficacy support',
#  'elemental army support',
#  'elemental focus support',
#  'elemental penetration support',
#  'elemental proliferation support',
#  'energy leech support',
#  'enlighten support',
#  'faster casting support',
#  'feeding frenzy support',
#  'hextouch support',
#  'high-impact mine support',
#  'ignite proliferation support',
#  'immolate support',
#  'impending doom support',
#  'increased area of effect support',
#  'increased critical damage support',
#  'increased critical strikes support',
#  'infernal legion support',
#  'infused channelling support',
#  'innervate support',
#  'intensify support',
#  'item rarity support',
#  'lightning penetration support',
#  'meat shield support',
#  'minefield support',
#  'minion damage support',
#  'minion life support',
#  'minion speed support',
#  'physical to lightning support',
#  'pinpoint support',
#  'power charge on critical support',
#  'predator support',
#  'spell cascade support',
#  'spell echo support',
#  'summon phantasm support',
#  'swiftbrand support',
#  'trinity support',
#  'unbound ailments support',
#  'unleash support']

# %%
def allSubstrings(string):
    test_str = str(string)
    substrings = [test_str[i: j] for i in range(len(test_str)) for j in range(i + 1, len(test_str) + 1)]
    sorted_substrings = sorted(substrings, key = len)
    return sorted_substrings

def createSubstringList(gem_tab):
    substring_list = []
    for gem_name in gem_tab: 
        gem_substring = allSubstrings(gem_name)
        substring_list.append(gem_substring)
    return substring_list

def findUniqueSubstring(gem_tab, substring_list):
    unique_substring_dict = {}
    for i in range(len(substring_list)):
        gem_name = gem_tab[i]
        for substring in substring_list[i]:
            has_match = False
            for j in range(len(substring_list)):
                if i == j:
                    continue
                if substring in substring_list[j]:
                    has_match = True
                    break
            if has_match == False: 
                unique_substring_dict[gem_name] = substring
                break
    return unique_substring_dict

findUniqueSubstring(sorted_gems[0], createSubstringList(sorted_gems[0]))
# Out:
# {'absolution': 'bs',
#  'ancestral cry': 'ral c',
#  'ancestral protector': 'l p',
#  'ancestral warchief': ' w',
#  'anger': 'ger',
#  'animate guardian': 'di',
#  'battlemages cry': 'tl',
#  'berserk': 'be',
#  'bladestorm': 'bla',
#  'blood and sand': 'od ',
#  'boneshatter': 'nes',
#  'chain hook': 'ai',
#  'cleave': 'cl',
#  'consecrated path': 'ns',
#  'corrupting fever': 'rr',
#  'decoy totem': 'oy',
#  'defiance banner': 'def',
#  'determination': 'det',
#  'devouring totem': 'dev',
#  'dominating blow': 'do',
#  'dread banner': 'dr',
#  'earthquake': 'q',
#  'earthshatter': 'hs',
#  'enduring cry': 'du',
#  'exsanguinate': 'xs',
#  'flame link': 'me l',
#  'flesh and stone': 'h ',
#  'generals cry': 'gen',
#  'glacial hammer': 'gl',
#  'ground slam': 'gr',
#  'heavy strike': 'vy',
#  'herald of ash': 'f a',
#  'herald of purity': 'f p',
#  'holy flame totem': 'hol',
#  'ice crash': 'ice',
#  'immortal call': 'ca',
#  'infernal blow': 'l b',
#  'infernal cry': 'nal c',
#  'intimidating cry': 'da',
#  'leap slam': 'p ',
#  'molten shell': ' sh',
#  'molten strike': 'en st',
#  'perforate': 'rf',
#  'petrified blood': 'if',
#  'pride': 'pri',
#  'protective link': 'iv',
#  'punishment': 'hm',
#  'purity of fire': 'ir',
#  'rage vortex': ' v',
#  'rallying cry': 'yi',
#  'reap': 'reap',
#  'reckoning': 'ko',
#  'rejuvenation totem': 'j',
#  'searing bond': 'sea',
#  'seismic cry': 'ei',
#  'shield charge': 'rg',
#  'shield crush': 'us',
#  'shockwave totem': 'oc',
#  'smite': 'mit',
#  'static strike': 'sta',
#  'steelskin': 'sk',
#  'summon flame golem': 'n f',
#  'summon stone golem': 'ne ',
#  'sunder': 'sun',
#  'sweep': 'sw',
#  'tectonic slam': 'nic',
#  'vengeance': 'eng',
#  'vigilant strike': 'ig',
#  'vitality': 'vit',
#  'vulnerability': 'vu',
#  'war banner': 'r ',
#  'warlords mark': 'rl'}

# %%
no_unique_substring = {
    'arc': 'arc$', 
    'volley support': '^vol', 
    'vortex': '^vor', 
    'wither': 'wither$', 
    'dash': '^dash', 
    'stun support': '^stun'
}

# %%
for val in no_unique_substring:
    print(val)
# Out:
# arc
# volley support
# vortex
# wither
# dash
# stun support

# %%
def gems_lower(gems):
    return [gem.lower() for gem in gems]

def match_substring_to_fullstring(substring, string_list):
    for string in string_list:
        if substring in string:
            return string
    return "String not found."
        
def populate_substring_list(gems, string_len):
    gems = gems_lower(gems)
    curr_substrings = []
    for gem in gems:
        curr_substring = ""
        lst = []
        i = 0
        while curr_substring != gem[-string_len:]:
            curr_substring = gem[i:i+string_len]
            lst.append(curr_substring)
            i += 1
        curr_substrings.append(lst)
    return curr_substrings

def generate_unique_substring(gems):
    mod_to_substring_dict = {}
    string_len = 3
    match_no_unique = [val for val in gems if val in no_unique_substring]
    while len(mod_to_substring_dict) < len(gems)-len(match_no_unique):
        substring_lists = populate_substring_list(gems, string_len)

        num_substring_lists = len(substring_lists)
        for x in range(num_substring_lists):
            curr_substring_list = substring_lists[x]
            for substring in curr_substring_list:
                fullstring = match_substring_to_fullstring(substring, gems_lower(gems))
                
                if fullstring in mod_to_substring_dict:
                    continue
                substring_has_dupe = False
                for y in range(num_substring_lists): 
                    compare_substring_list = substring_lists[y]
                    if compare_substring_list == curr_substring_list:
                        continue
                    if substring in compare_substring_list:
                        substring_has_dupe = True
                        continue
                if substring_has_dupe == False:
                    # skip over 3 char substrings with space
                    if len(substring) == 3 and " " in substring:
                        continue
                    if "x%" in substring:
                        substring = substring.replace("x%", "\d+%")
                    mod_to_substring_dict[fullstring] = substring
                    #print(fullstring, substring)
                    break
        string_len += 1
    
    for val in match_no_unique:
        mod_to_substring_dict[val] = no_unique_substring[val]
    return mod_to_substring_dict

# %%
red_gems = sorted_gems[0] + sorted_gems[1]
green_gems  = sorted_gems[2] + sorted_gems[3]
blue_gems = sorted_gems[4] + sorted_gems[5]

# %%
if 'stun support' in no_unique_substring:
    print("ho")
# Out:
# ho

# %%
red_gems
# Out:
# ['absolution',
#  'ancestral cry',
#  'ancestral protector',
#  'ancestral warchief',
#  'anger',
#  'animate guardian',
#  'battlemages cry',
#  'berserk',
#  'bladestorm',
#  'blood and sand',
#  'boneshatter',
#  'chain hook',
#  'cleave',
#  'consecrated path',
#  'corrupting fever',
#  'decoy totem',
#  'defiance banner',
#  'determination',
#  'devouring totem',
#  'dominating blow',
#  'dread banner',
#  'earthquake',
#  'earthshatter',
#  'enduring cry',
#  'exsanguinate',
#  'flame link',
#  'flesh and stone',
#  'generals cry',
#  'glacial hammer',
#  'ground slam',
#  'heavy strike',
#  'herald of ash',
#  'herald of purity',
#  'holy flame totem',
#  'ice crash',
#  'immortal call',
#  'infernal blow',
#  'infernal cry',
#  'intimidating cry',
#  'leap slam',
#  'molten shell',
#  'molten strike',
#  'perforate',
#  'petrified blood',
#  'pride',
#  'protective link',
#  'punishment',
#  'purity of fire',
#  'rage vortex',
#  'rallying cry',
#  'reap',
#  'reckoning',
#  'rejuvenation totem',
#  'searing bond',
#  'seismic cry',
#  'shield charge',
#  'shield crush',
#  'shockwave totem',
#  'smite',
#  'static strike',
#  'steelskin',
#  'summon flame golem',
#  'summon stone golem',
#  'sunder',
#  'sweep',
#  'tectonic slam',
#  'vengeance',
#  'vigilant strike',
#  'vitality',
#  'vulnerability',
#  'war banner',
#  'warlords mark',
#  'added fire damage support',
#  'ancestral call support',
#  'arrogance support',
#  'ballista totem support',
#  'behead support',
#  'bloodlust support',
#  'bloodthirst support',
#  'brutality support',
#  'burning damage support',
#  'cast on melee kill support',
#  'cast when damage taken support',
#  'chance to bleed support',
#  'cold to fire support',
#  'cruelty support',
#  'damage on full life support',
#  'divine blessing support',
#  'earthbreaker support',
#  'elemental damage with attacks support',
#  'empower support',
#  'endurance charge on melee stun support',
#  'eternal blessing support',
#  'fire penetration support',
#  'fist of war support',
#  'fortify support',
#  'generosity support',
#  'increased duration support',
#  'inspiration support',
#  'iron grip support',
#  'iron will support',
#  'knockback support',
#  'less duration support',
#  'life gain on hit support',
#  'life leech support',
#  'lifetap support',
#  'maim support',
#  'melee physical damage support',
#  'melee splash support',
#  'multiple totems support',
#  'multistrike support',
#  'pulverise support',
#  'rage support',
#  'ruthless support',
#  'shockwave support',
#  'spell totem support',
#  'stun support',
#  'urgent orders support']

# %%
generate_unique_substring(blue_gems)
# Out:
# {'arcane cloak': 'clo',
#  'arcanist brand': 'ani',
#  'armageddon brand': 'rma',
#  'assassins mark': 'ass',
#  'bane': 'ban',
#  'blazing salvo': 'laz',
#  'bodyswap': 'bod',
#  'brand recall': 'rec',
#  'clarity': 'lar',
#  'cold snap': 'col',
#  'conductivity': 'ndu',
#  'contagion': 'tag',
#  'conversion trap': 'nve',
#  'convocation': 'nvo',
#  'crackling lance': 'cra',
#  'creeping frost': 'eep',
#  'dark pact': 'dar',
#  'despair': 'esp',
#  'destructive link': 'ive',
#  'discharge': 'sch',
#  'discipline': 'sci',
#  'divine ire': 'div',
#  'elemental weakness': 'wea',
#  'energy blade': 'lad',
#  'enfeeble': 'enf',
#  'essence drain': 'sse',
#  'eye of winter': 'eye',
#  'fireball': 'reb',
#  'firestorm': 'res',
#  'flame dash': 'das',
#  'flameblast': 'meb',
#  'flammability': 'amm',
#  'flesh offering': 'fle',
#  'forbidden rite': 'for',
#  'freezing pulse': 'eez',
#  'frost bomb': 'bom',
#  'frostbite': 'tbi',
#  'frostblink': 'tbl',
#  'frostbolt': 'tbo',
#  'glacial cascade': 'gla',
#  'herald of thunder': 'ral',
#  'hexblast': 'exb',
#  'hydrosphere': 'hyd',
#  'ice spear': 'pea',
#  'icicle mine': 'ici',
#  'incinerate': 'nci',
#  'lightning tendrils': 'ndr',
#  'lightning warp': 'war',
#  'malevolence': 'mal',
#  'manabond': 'man',
#  'orb of storms': 'rms',
#  'penance brand': 'ena',
#  'purifying flame': 'rif',
#  'pyroclast mine': 'pyr',
#  'raise spectre': 'pec',
#  'raise zombie': 'zom',
#  'righteous fire': 'rig',
#  'rolling magma': 'agm',
#  'scorching ray': 'sco',
#  'shock nova': 'sho',
#  'sigil of power': 'sig',
#  'siphoning trap': 'oni',
#  'soulrend': 'ulr',
#  'spark': 'par',
#  'spellslinger': 'lls',
#  'stormbind': 'bin',
#  'stormblast mine': 'mbl',
#  'summon carrion golem': 'car',
#  'summon holy relic': 'hol',
#  'summon raging spirit': 'rag',
#  'summon reaper': 'eap',
#  'summon skeletons': 'ske',
#  'summon skitterbots': 'ski',
#  'tempest shield': 'emp',
#  'void sphere': 'voi',
#  'voltaxic burst': 'lta',
#  'vortex': '^vor',
#  'wave of conviction': 'wav',
#  'wintertide brand': 'ert',
#  'wither': 'wither$',
#  'wrath': 'wra',
#  'zealotry': 'zea',
#  'archmage support': 'chm',
#  'blasphemy support': 'asp',
#  'blastchain mine support': 'stc',
#  'bonechill support': 'nec',
#  'cast when stunned support': 'whe',
#  'cast while channelling support': 'whi',
#  'combustion support': 'com',
#  'concentrated effect support': 'onc',
#  'controlled destruction support': 'tro',
#  'decay support': 'dec',
#  'efficacy support': 'ffi',
#  'elemental army support': 'rmy',
#  'elemental focus support': 'foc',
#  'energy leech support': 'lee',
#  'enlighten support': 'enl',
#  'faster casting support': 'fas',
#  'feeding frenzy support': 'edi',
#  'hextouch support': 'ext',
#  'high-impact mine support': 'hig',
#  'ignite proliferation support': 'ign',
#  'immolate support': 'imm',
#  'impending doom support': 'ndi',
#  'increased area of effect support': 'are',
#  'increased critical strikes support': 'rik',
#  'infernal legion support': 'ern',
#  'infused channelling support': 'nfu',
#  'innervate support': 'inn',
#  'intensify support': 'ens',
#  'item rarity support': 'rar',
#  'meat shield support': 'mea',
#  'minefield support': 'nef',
#  'minion speed support': 'pee',
#  'physical to lightning support': 'phy',
#  'pinpoint support': 'inp',
#  'predator support': 'pre',
#  'spell echo support': 'cho',
#  'summon phantasm support': 'pha',
#  'swiftbrand support': 'swi',
#  'unbound ailments support': 'unb',
#  'unleash support': 'unl',
#  'arc': 'arc$',
#  'ball lightning': 'all ',
#  'blight': 'blig',
#  'bone offering': 'one ',
#  'flame surge': 'me s',
#  'flame wall': 'me w',
#  'frost wall': 't wa',
#  'ice nova': 'ce n',
#  'kinetic blast': 'c bl',
#  'kinetic bolt': 'c bo',
#  'lightning spire trap': 'pire',
#  'power siphon': 'er s',
#  'purity of elements': 'f el',
#  'purity of lightning': 'of l',
#  'soul link': 'oul ',
#  'spirit offering': 'rit ',
#  'storm brand': 'm br',
#  'storm burst': 'm bu',
#  'storm call': 'rm c',
#  'summon chaos golem': 'n ch',
#  'summon lightning golem': 'ng g',
#  'winter orb': 'er o',
#  'added chaos damage support': 'os d',
#  'added lightning damage support': 'ed l',
#  'charged mines support': 'rged',
#  'elemental penetration support': 'l pe',
#  'elemental proliferation support': 'l pr',
#  'increased critical damage support': 'al d',
#  'lightning penetration support': 'g pe',
#  'minion damage support': 'on d',
#  'minion life support': ' lif',
#  'power charge on critical support': 'r ch',
#  'spell cascade support': 'll c',
#  'trinity support': 'trin'}

# %%
match_substring_to_fullstring("bso", gems_lower(lst))
# Out:
# 'absolution'

# %%
generate_unique_substring(lst)
# Out:
# absolution abs
# ancestral warchief ief
# animate guardian gua
# battlemages cry ttl
# berserk ber
# chain hook hoo
# consecrated path nse
# corrupting fever orr
# decoy totem coy
# defiance banner fia
# devouring totem dev
# dominating blow dom
# dread banner dre
# earthquake thq
# earthshatter ths
# exsanguinate exs
# generals cry als
# glacial hammer ham
# ground slam gro
# heavy strike avy
# ice crash ras
# immortal call mor
# intimidating cry nti
# molten shell she
# perforate erf
# petrified blood pet
# pride pri
# punishment uni
# rallying cry lly
# reckoning eck
# rejuvenation totem rej
# searing bond sea
# shield crush rus
# smite mit
# static strike tat
# steelskin els
# sunder sun
# sweep swe
# vengeance eng
# vigilant strike vig
# vitality ita
# vulnerability vul
# warlords mark arl
# arrogance support rog
# behead support beh
# bloodlust support odl
# bloodthirst support odt
# brutality support bru
# cast on melee kill support kil
# cast when damage taken support tak
# cruelty support rue
# damage on full life support ful
# earthbreaker support thb
# fist of war support fis
# generosity support ero
# inspiration support nsp
# iron grip support gri
# knockback support kno
# life gain on hit support gai
# lifetap support fet
# maim support mai
# multiple totems support ems
# multistrike support tis
# pulverise support ulv
# ruthless support uth
# urgent orders support rde
# ambush amb
# animate weapon apo
# arctic armour rct
# artillery ballista ler
# blade flurry flu
# bladefall efa
# caustic arrow cau
# cobra lash cob
# cremation rem
# cyclone cyc
# desecrate ese
# double strike dou
# dual strike dua
# ensnaring arrow nsn
# ethereal knives kni
# flamethrower trap met
# flicker strike ick
# galvanic arrow gal
# grace gra
# hatred atr
# herald of agony ago
# intuitive link ntu
# lacerate cer
# mirror arrow irr
# phase run run
# plague bearer lag
# poachers mark poa
# poisonous concoction ono
# precision eci
# puncture unc
# rain of arrows ows
# riposte ipo
# scourge arrow cou
# shrapnel ballista shr
# siege ballista sie
# smoke mine smo
# snipers mark sni
# spectral helix lix
# splitting steel tti
# unearth une
# vampiric link vam
# venom gyre eno
# viper strike vip
# whirling blades irl
# wild strike ild
# withering step tep
# additional accuracy support ddi
# advanced traps support adv
# block chance reduction support loc
# close combat support ose
# cluster traps support clu
# culling strike support cul
# deadly ailments support adl
# enhance support enh
# fork support ork
# hypothermia support hyp
# impale support pal
# nightblade support nig
# onslaught support nsl
# pierce support pie
# point blank support ank
# slower projectiles support slo
# swift assembly support sem
# vicious projectiles support cio
# vile toxins support vil
# void manipulation support ipu
# arcane cloak loa
# armageddon brand rma
# assassins mark ssa
# blazing salvo laz
# bodyswap bod
# clarity lar
# cold snap nap
# contagion tag
# conversion trap nve
# convocation nvo
# crackling lance ckl
# creeping frost epi
# dark pact dar
# despair esp
# discharge sch
# discipline sci
# elemental weakness akn
# enfeeble enf
# essence drain sen
# eye of winter eye
# fireball reb
# firestorm res
# flameblast meb
# flammability mma
# forbidden rite rbi
# freezing pulse eez
# frost bomb bom
# frostbite tbi
# frostbolt tbo
# herald of thunder thu
# hexblast exb
# hydrosphere hyd
# ice spear pea
# icicle mine cic
# lightning tendrils ndr
# lightning warp arp
# malevolence mal
# manabond nab
# orb of storms rms
# penance brand nan
# purifying flame fyi
# pyroclast mine pyr
# raise zombie zom
# righteous fire rig
# rolling magma agm
# scorching ray orc
# sigil of power sig
# soulrend ulr
# spark par
# spellslinger lls
# stormbind bin
# summon carrion golem car
# summon holy relic rel
# summon raging spirit gin
# summon reaper ape
# summon skeletons ske
# summon skitterbots kit
# voltaxic burst lta
# wave of conviction nvi
# wintertide brand ert
# wrath wra
# zealotry zea
# archmage support chm
# blasphemy support asp
# blastchain mine support stc
# bonechill support nec
# cast when stunned support unn
# concentrated effect support cen
# controlled destruction support tro
# decay support cay
# efficacy support ffi
# elemental army support rmy
# enlighten support enl
# feeding frenzy support edi
# hextouch support ext
# high-impact mine support hig
# ignite proliferation support ign
# impending doom support ndi
# increased critical strikes support kes
# infernal legion support leg
# infused channelling support nfu
# innervate support inn
# intensify support nsi
# item rarity support rar
# meat shield support mea
# minefield support nef
# minion speed support pee
# pinpoint support inp
# predator support eda
# spell echo support cho
# summon phantasm support tas
# swiftbrand support ftb
# unbound ailments support unb
# unleash support unl
# ancestral protector ctor
# anger ange
# blood and sand od a
# boneshatter ones
# cleave clea
# determination dete
# enduring cry duri
# flame link me l
# flesh and stone sh a
# herald of ash f as
# herald of purity f pu
# holy flame totem ly f
# leap slam leap
# purity of fire of f
# rage vortex ge v
# seismic cry ic c
# summon flame golem n fl
# summon stone golem ne g
# tectonic slam cton
# war banner ar b
# added fire damage support ed f
# ballista totem support ta t
# chance to bleed support to b
# cold to fire support d to
# divine blessing support ne b
# elemental damage with attacks support ge w
# empower support mpow
# endurance charge on melee stun support uran
# eternal blessing support tern
# fire penetration support re p
# fortify support fort
# increased duration support d du
# iron will support on w
# less duration support ss d
# life leech support fe l
# melee physical damage support ee p
# melee splash support  spl
# shockwave support ve s
# spell totem support ll t
# bear trap ear
# blade trap de t
# blade vortex de v
# blast rain st r
# blink arrow ink
# blood rage od r
# detonate dead deto
# elemental hit l hi
# explosive arrow ve a
# explosive concoction ve c
# haste hast
# ice shot e sh
# lancing steel anci
# pestilent strike esti
# reave reav
# seismic trap ic t
# shattering steel teri
# spectral shield throw l sh
# spectral throw l th
# split arrow lit
# storm rain rm r
# summon ice golem on i
# temporal chains l ch
# temporal rift al r
# tornado shot ado
# toxic rain oxic
# volatile dead vola
# added cold damage support d co
# arrow nova support row
# blind support lind
# cast on death support n de
# chain support in s
# chance to flee support o fl
# chance to poison support to p
# cold penetration support ld p
# critical strike affliction support ke a
# faster attacks support er a
# focused ballista support cuse
# greater volley support er v
# ice bite support e bi
# lesser multiple projectiles support sser
# mana leech support ana
# mark on hit support rk o
# mirage archer support mira
# second wind support seco
# swift affliction support t af
# trap and mine damage support ap a
# withering touch support  tou
# arcanist brand cani
# bane bane
# blight blig
# bone offering ne o
# brand recall nd r
# conductivity ondu
# divine ire ne i
# energy blade gy b
# flame dash me d
# flame surge me s
# flame wall me w
# flesh offering sh o
# frost wall t wa
# frostblink stbl
# ice nova ce n
# incinerate inci
# kinetic blast c bl
# kinetic bolt c bo
# lightning spire trap pire
# power siphon r si
# purity of elements f el
# purity of lightning of l
# raise spectre ctre
# shock nova ck n
# siphoning trap honi
# soul link oul
# spirit offering rit
# storm brand m br
# storm burst m bu
# storm call rm c
# stormblast mine rmbl
# summon chaos golem n ch
# summon lightning golem ng g
# tempest shield empe
# void sphere id s
# winter orb er o
# added chaos damage support os d
# added lightning damage support ed l
# cast while channelling support  whi
# charged mines support ed m
# combustion support ombu
# elemental focus support al f
# elemental penetration support l pe
# energy leech support gy l
# faster casting support r ca
# immolate support mmol
# increased area of effect support ed a
# lightning penetration support g pe
# physical to lightning support to l
# power charge on critical support r ch
# spell cascade support ll c
# trinity support trin
# bladestorm adest
# infernal blow l blo
# infernal cry nal c
# molten strike n str
# protective link tecti
# reap reap
# shield charge ld ch
# shockwave totem ave t
# ancestral call support call
# blade blast ade b
# charged dash ged d
# explosive trap ive t
# frost blades st bl
# ice trap ice t
# charged traps support ged t
# faster projectiles support ter p
# greater multiple projectiles support ter m
# multiple traps support le tr
# trap support rap s
# ball lightning ball
# frost shield ost s
# glacial cascade ial c
# arcane surge support ane s
# minion damage support ion d
# minion life support ion l
# ancestral cry ral cr
# fire trap fire t
# herald of ice d of i
# purity of ice y of i
# barrage support rrage
# cast on critical strike support t on c
# destructive link ructiv
# elemental proliferation support tal pr
# burning damage support rning d
# burning arrow rning a
# frenzy frenzy
# lightning arrow tning a
# lightning strike ning st
# increased critical damage support tical d
# barrage barrage
# tornado tornado
# lightning trap tning tr
# rage support rage support
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-722488569cea> in <module>
# ----> 1 generate_unique_substring(lst)
#
# <ipython-input-30-190bff638c74> in generate_unique_substring(gems)
#      32             curr_substring_list = substring_lists[x]
#      33             for substring in curr_substring_list:
# ---> 34                 fullstring = match_substring_to_fullstring(substring, gems_lower(gems))
#      35                 if fullstring in mod_to_substring_dict:
#      36                     continue
#
# <ipython-input-30-190bff638c74> in match_substring_to_fullstring(substring, string_list)
#       3
#       4 def match_substring_to_fullstring(substring, string_list):
# ----> 5     for string in string_list:
#       6         if substring in string:
#       7             return string
#
# KeyboardInterrupt:

# %%
red1_substring = findUniqueSubstring(sorted_gems[0], createSubstringList(sorted_gems[0]))
red2_substring = findUniqueSubstring(sorted_gems[1], createSubstringList(sorted_gems[1]))
green1_substring = findUniqueSubstring(sorted_gems[2], createSubstringList(sorted_gems[2]))
green2_substring = findUniqueSubstring(sorted_gems[3], createSubstringList(sorted_gems[3]))
blue1_substring = findUniqueSubstring(sorted_gems[4], createSubstringList(sorted_gems[4]))
blue2_substring = findUniqueSubstring(sorted_gems[5], createSubstringList(sorted_gems[5]))

# %%
blue2_substring
# Out:
# {'added chaos damage': 'ao',
#  'added lightning damage': 'd l',
#  'arcane surge': 'ur',
#  'archmage': 'hm',
#  'blasphemy': 'asp',
#  'blastchain mine': 'tc',
#  'bonechill': 'bon',
#  'cast when stunned': 'tu',
#  'cast while channelling': 'whi',
#  'charged mines': 'ged',
#  'combustion': 'mb',
#  'concentrated effect': 'ce',
#  'controlled destruction': 'ru',
#  'decay': 'ay',
#  'efficacy': 'cy',
#  'elemental army': 'rm',
#  'elemental focus': 'fo',
#  'elemental penetration': 'l pe',
#  'elemental proliferation': 'l pr',
#  'energy leech': 'gy',
#  'enlighten': 'enl',
#  'faster casting': 'fa',
#  'feeding frenzy': 'z',
#  'hextouch': 'x',
#  'high-impact mine': '-',
#  'ignite proliferation': 'gn',
#  'immolate': 'imm',
#  'impending doom': 'do',
#  'increased area of effect': 'a ',
#  'increased critical damage': 'l d',
#  'increased critical strikes': 'k',
#  'infernal legion': 'rn',
#  'infused channelling': 'fu',
#  'innervate': 'v',
#  'intensify': 'ns',
#  'item rarity': 'm ',
#  'lightning penetration': 'g p',
#  'meat shield': 'mea',
#  'minefield': 'nef',
#  'minion damage': 'n d',
#  'minion life': 'n l',
#  'minion speed': ' sp',
#  'physical to lightning': 'hy',
#  'pinpoint': 'pi',
#  'power charge on critical': 'ow',
#  'predator': 'or',
#  'spell cascade': 'sc',
#  'spell echo': 'ho',
#  'summon phantasm': 'um',
#  'swiftbrand': 'sw',
#  'trinity': 'rin',
#  'unbound ailments': 'nb',
#  'unleash': 'unl'}

# %%
def getSkillGems(pob_url):
    build = pobapi.from_url(pob_url)
    skills = build.skill_gems
    skill_names = [skill.name for skill in skills]
    return skill_names

getSkillGems("https://pastebin.com/zYiZrW26")
# Out:
# ['Fireball',
#  'Burning Damage',
#  'Deadly Ailments',
#  'Unbound Ailments',
#  'Ignite Proliferation',
#  'Swift Affliction']

# %%
def getGemSubstrings(skill_gems):
    gem_strings = [[], [], [], [], [], []]
    for raw_gem in skill_gems:
        gem = str.lower(raw_gem)
        if gem in red1_substring: 
            gem_strings[0].append(red1_substring[gem])
        elif gem in red2_substring: 
            gem_strings[1].append(red2_substring[gem])
        elif gem in green1_substring: 
            gem_strings[2].append(green1_substring[gem])
        elif gem in green2_substring: 
            gem_strings[3].append(green2_substring[gem])
        elif gem in blue1_substring: 
            gem_strings[4].append(blue1_substring[gem])
        elif gem in blue2_substring: 
            gem_strings[5].append(blue2_substring[gem])
    return gem_strings

# %%
getGemSubstrings(getSkillGems("https://pastebin.com/zYiZrW26"))
# Out:
# [[], ['bu'], [], ['dl', 't af'], ['reb'], ['nb', 'gn']]

# %%
def listToCopy(gem_string):
    string = '"'
    for i in range(len(gem_string)): 
        if len(string) + len(gem_string[i]) >= MAX_LEN-1:
            string += '"'
            print(string)
            string = '"'
        string += gem_string[i]
        if i < len(gem_string) - 1: 
            string += '|'
    string += '"'
    print(string)
    return
def substringToCopy(gem_strings):
    print("Active Red Gems: ")
    listToCopy(gem_strings[0])
    print("Support Red Gems: ")
    listToCopy(gem_strings[1])
    print("Active Green Gems: ")
    listToCopy(gem_strings[2])
    print("Support Green Gems: ")
    listToCopy(gem_strings[3])
    print("Active Blue Gems: ")
    listToCopy(gem_strings[4])
    print("Support Blue Gems: ")
    listToCopy(gem_strings[5])
substringToCopy(getGemSubstrings(getSkillGems("https://pastebin.com/Z2UweZ2n")))
# Out:
# Active Red Gems:
# "ne "
# Support Red Gems:
# "ik|ph|os"
# Active Green Gems:
# "atr|ese"
# Support Green Gems:
# "ter m|hy"
# Active Blue Gems:
# "pec| z|nvo|tt|one|mp|ed|tbi| da"
# Support Blue Gems:
# "n d|ho|n d|or|ru|mea|rm|x"

# %%
listToCopy(getGemSubstrings(sorted_gems[5])[5])
# Out:
# "ao|d l|ur|hm|asp|tc|bon|tu|whi|ged|mb|ce|ru|"
# "ay|cy|rm|fo|l pe|l pr|gy|enl|fa|z|x|-|gn|imm|"
# "do|a |l d|k|rn|fu|v|ns|m |g p|mea|nef|n d|n l|"
# " sp|hy|pi|ow|or|sc|ho|um|sw|rin|nb|unl"

# %%
getGemSubstrings(sorted_gems[5])[5]
# Out:
# ['ao',
#  'd l',
#  'ur',
#  'hm',
#  'asp',
#  'tc',
#  'bon',
#  'tu',
#  'whi',
#  'ged',
#  'mb',
#  'ce',
#  'ru',
#  'ay',
#  'cy',
#  'rm',
#  'fo',
#  'l pe',
#  'l pr',
#  'gy',
#  'enl',
#  'fa',
#  'z',
#  'x',
#  '-',
#  'gn',
#  'imm',
#  'do',
#  'a ',
#  'l d',
#  'k',
#  'rn',
#  'fu',
#  'v',
#  'ns',
#  'm ',
#  'g p',
#  'mea',
#  'nef',
#  'n d',
#  'n l',
#  ' sp',
#  'hy',
#  'pi',
#  'ow',
#  'or',
#  'sc',
#  'ho',
#  'um',
#  'sw',
#  'rin',
#  'nb',
#  'unl']
